# %%
### import libraries
import argparse
import json
import requests
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
### credentials
# go to graphQL explorer & copy the token
# debug & extend the token - https://developers.facebook.com/tools/debug/accesstoken/?access_token=1188185338645694%7Clu6paxlAjEydJwExj0DCZqR-TRg&version=v16.0
ACCESS_TOKEN = "EAALF3LZBKPzcBAHtweCQRqwtsDSzgZAN4ZALhNlZAWWDsO6OEtUWUnLTrSLl9mtWMYyrWIDIRKL6sbgWo27NixMoBXztLDyzbH2JMBfsFfDmsxniYrmexsziPXpD9iK7MfgYWYsBlAZBAwUmgxyglQUPD5MIyoDRI8UkwciwxQqpDjJJG0VPf3ZCGUbnkFIzoZD"

# %%
### functions

def calculate_impressions_midpoint(data):
    """Calculate impressions midpoint"""
    # Convert from a string of characters into an integer
    upper_bound = int(data["impressions"]["upper_bound"])
    lower_bound = int(data["impressions"]["lower_bound"])

    return round((upper_bound + lower_bound) / 2)

def calculate_impressions_by_region(data, impressions):
    """Calculate impressions by regions"""
    # Create a new dict to contain the results
    result = {}

    # Loop through each region and calculate the impressions
    for chunk in data["delivery_by_region"]:
        result[chunk["region"]] = round(impressions * float(chunk["percentage"]))

    return result

def calculate_impressions_by_gender(data, impressions):
    """Calculates impressions by gender"""
    # Create a new dict to contain the results. The categories are pre-populated with 0s.
    results = {"male": 0, "female": 0, "unknown": 0}

    # Loop through demographic data
    for d in data["demographic_distribution"]:
        # Let's break this expression down:
        # 1. result[d["gender"]] looks for the key in the result dict that matches d["gender"]
        # 2. += is a short hand operator for addition and assignment. e.g. foo +=1 is the same
        #    as foo = foo + 1
        # 3. float(d["percentage"]) converts the JSON data into a decimal number (programmers
        #    call those floats because the decimal can move around).
        # 4. round(impressions * float(d["percentage"])) multiplies the percentage by the
        #    impressions and rounds up to the nearest integer
        results[d["gender"]] += round(impressions * float(d["percentage"]))

    return results

def calculate_impressions_by_age(data, impressions):
    """Calculate impressions by age"""
    # Create a new default dict to contain the results. The default dict makes any new element
    # default to a value specified by the user. In our case we're defaulting to an integer 0.
    # int is actually a function that retuns 0 when called with no arguments
    results = defaultdict(int)

    # Loop through the demographic data and add up the impressions
    for d in data["demographic_distribution"]:
        # Let's break this expression down:
        # 1. result[d["age"]] looks for the key in the result dict that matches d["age"]. If
        #    there is no key that matches d["age"] the default dict will make one with the value
        #    of int(), which is always 0.
        # 2. += is a short hand operator for addition and assignment. e.g. foo +=1 is the same
        #    as foo = foo + 1
        # 3. float(d["percentage"]) converts the JSON data into a decimal number (programmers
        #    call those floats because the decimal can move around).
        # 4. round(impressions * float(d["percentage"])) multiplies the percentage by the
        #    impressions and rounds up to the nearest integer
        results[d["age"]] += round(impressions * float(d["percentage"]))

    return results

# %%
### list of page IDs
idList = ['106039214814684',
'102281724942742',
'738063612887865',
'341751646428117',
'591566840920364',
'105502284969626',
'49560242814',
'101691091213750',
'113891694102',
'292970844058835',
'100801038449520',
'108095672108380',
'111394533709201',
'107500120800840',
'101242238726088',
'237209147160346',
'110124925319299',
'396341921119746',
'108203188195224',
'106656845034469',
'47710973068',
'482100658584410']

# %%
"""Entrypoint of the program"""

# Store the paginated data in here
data = []

# create dataframe
df = pd.DataFrame()

# for each item in the list, store their data in the pandas dataframe

# This might work for our request
for i in idList:
    print(i)
    response = requests.get("https://graph.facebook.com/v5.0/ads_archive", params={
    "access_token": ACCESS_TOKEN,
    "ad_type": "POLITICAL_AND_ISSUE_ADS",
    "ad_active_status": "ALL",
    "search_page_ids": i,
    "ad_reached_countries": ["US"],
    "ad_delivery_date_min": "2018-05-24",
    "ad_delivery_date_max": "2023-06-11",
    "fields": "id, ad_delivery_start_time, ad_delivery_stop_time, ad_snapshot_url, bylines, delivery_by_region, demographic_distribution, impressions, publisher_platforms, spend, ad_creative_bodies, ad_creative_link_captions, ad_creative_link_descriptions, ad_creative_link_titles, page_name, page_id"
})
    # Get the json document and pull out the next link and the data
    json = response.json()
    
    try:
        next_link = json['paging']['next']
        data = data + json['data']
    except KeyError:
        continue

    while next_link:
      print('.', end='')
      response = requests.get(next_link)
      json = response.json()
      if 'paging' not in json:
        break
      next_link = json['paging']['next']
      data = data + json['data']
    print('\n')

    # append data to dataframe
    res = pd.json_normalize(data)
    df.append(res)
# Out:
# 106039214814684
# .....
#
# 102281724942742
# .........................................................................................
#
# 738063612887865
# .......................................................................................................................
#
# 341751646428117
# ..
#
# 591566840920364
# ............................................
#
# 105502284969626
# .
#
# 49560242814
# ..........................................................................................
#
# 101691091213750
# .........................................................................................
#
# 113891694102
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#
# 292970844058835
# .
#
# 100801038449520
# ..............................................................................
#
# 108095672108380
# ..
#
# 111394533709201
# .
#
# 107500120800840
# .............
#
# 101242238726088
# .............
#
# 237209147160346
# ..................
#
# 110124925319299
# .
#
# 396341921119746
# ......
#
# 108203188195224
# .........
#
# 106656845034469
# ........
#
# 47710973068
# ..............................................................................
#
# 482100658584410
# .........................................

# %%
res
# Out:
#                      id ad_delivery_start_time ad_delivery_stop_time  \
# 0      1343142396186676             2022-01-13            2022-05-31
# 1       619401349138540             2022-01-13            2022-05-31
# 2       879439772752678             2022-01-14            2022-05-31
# 3      1297817217381527             2022-01-13            2022-05-31
# 4      3090071534604776             2022-01-14            2022-05-31
# ...                 ...                    ...                   ...
# 34817   189303645276959             2018-07-31            2018-08-03
# 34818   192309774968058             2018-07-31            2018-08-03
# 34819   263101847818994             2018-07-31            2018-08-03
# 34820  1031653150337021             2018-05-09            2018-06-10
# 34821  1870122529956895             2018-05-09            2018-06-07
#
#                                          ad_snapshot_url  \
# 0      https://www.facebook.com/ads/archive/render_ad...
# 1      https://www.facebook.com/ads/archive/render_ad...
# 2      https://www.facebook.com/ads/archive/render_ad...
# 3      https://www.facebook.com/ads/archive/render_ad...
# 4      https://www.facebook.com/ads/archive/render_ad...
# ...                                                  ...
# 34817  https://www.facebook.com/ads/archive/render_ad...
# 34818  https://www.facebook.com/ads/archive/render_ad...
# 34819  https://www.facebook.com/ads/archive/render_ad...
# 34820  https://www.facebook.com/ads/archive/render_ad...
# 34821  https://www.facebook.com/ads/archive/render_ad...
#
#                            bylines  \
# 0      Affordable Energy Coalition
# 1      Affordable Energy Coalition
# 2      Affordable Energy Coalition
# 3      Affordable Energy Coalition
# 4      Affordable Energy Coalition
# ...                            ...
# 34817          We Stand For Energy
# 34818          We Stand For Energy
# 34819          We Stand For Energy
# 34820                          NaN
# 34821                          NaN
#
#                                       delivery_by_region  \
# 0      [{'percentage': '0.000545', 'region': 'Idaho'}...
# 1      [{'percentage': '0.000434', 'region': 'Idaho'}...
# 2      [{'percentage': '0.00037', 'region': 'Idaho'},...
# 3          [{'percentage': '1', 'region': 'Washington'}]
# 4      [{'percentage': '0.00191', 'region': 'Idaho'},...
# ...                                                  ...
# 34817    [{'percentage': '1', 'region': 'North Dakota'}]
# 34818    [{'percentage': '1', 'region': 'North Dakota'}]
# 34819    [{'percentage': '1', 'region': 'North Dakota'}]
# 34820        [{'percentage': '1', 'region': 'Virginia'}]
# 34821        [{'percentage': '1', 'region': 'Virginia'}]
#
#                                 demographic_distribution  \
# 0      [{'percentage': '0.000133', 'age': '13-17', 'g...
# 1      [{'percentage': '0.000106', 'age': '13-17', 'g...
# 2      [{'percentage': '0.000605', 'age': '18-24', 'g...
# 3      [{'percentage': '0.000242', 'age': '18-24', 'g...
# 4      [{'percentage': '0.000526', 'age': '18-24', 'g...
# ...                                                  ...
# 34817  [{'percentage': '0.001258', 'age': '18-24', 'g...
# 34818  [{'percentage': '0.000596', 'age': '18-24', 'g...
# 34819  [{'percentage': '0.001269', 'age': '18-24', 'g...
# 34820  [{'percentage': '0.001071', 'age': '18-24', 'g...
# 34821  [{'percentage': '0.001062', 'age': '18-24', 'g...
#
#                                      publisher_platforms  \
# 0                                  [facebook, instagram]
# 1                                  [facebook, instagram]
# 2                                  [facebook, instagram]
# 3                                  [facebook, instagram]
# 4                                  [facebook, instagram]
# ...                                                  ...
# 34817                              [facebook, instagram]
# 34818                              [facebook, instagram]
# 34819                              [facebook, instagram]
# 34820  [facebook, instagram, audience_network, messen...
# 34821  [facebook, instagram, audience_network, messen...
#
#                                       ad_creative_bodies  \
# 0      [Middle-class families are being pushed out of...
# 1      [Middle-class families are being pushed out of...
# 2      [Middle-class families are being pushed out of...
# 3      [Middle-class families are being pushed out of...
# 4      [Middle-class families are being pushed out of...
# ...                                                  ...
# 34817  [North Dakota is leading the way in energy inn...
# 34818  [Help keep energy bills low by supporting a br...
# 34819  [Wind energy helps create jobs in North Dakota...
# 34820  [The Army Corps of Engineers has signed off on...
# 34821  [The Atlantic Coast Pipeline will spur even fu...
#
#              ad_creative_link_captions  \
# 0      [affordableenergycoalition.org]
# 1      [affordableenergycoalition.org]
# 2      [affordableenergycoalition.org]
# 3      [affordableenergycoalition.org]
# 4      [affordableenergycoalition.org]
# ...                                ...
# 34817                              NaN
# 34818                              NaN
# 34819                              NaN
# 34820           [WeStandForEnergy.com]
# 34821           [WeStandForEnergy.com]
#
#                            ad_creative_link_descriptions  \
# 0                        [Tell the City What’s at Stake]
# 1                        [Tell the City What’s at Stake]
# 2                        [Tell the City What’s at Stake]
# 3                        [Tell the City What’s at Stake]
# 4                        [Tell the City What’s at Stake]
# ...                                                  ...
# 34817                                                NaN
# 34818                                                NaN
# 34819                                                NaN
# 34820        [Tell the State Water Board: We Want Jobs!]
# 34821  [Tell the State Water Control Board: Approve t...
#
#        ad_creative_link_titles                    page_name          page_id  \
# 0      [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
# 1      [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
# 2      [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
# 3      [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
# 4      [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
# ...                        ...                          ...              ...
# 34817                      NaN          We Stand For Energy  482100658584410
# 34818                      NaN          We Stand For Energy  482100658584410
# 34819                      NaN          We Stand For Energy  482100658584410
# 34820     [Take Action Today!]          We Stand For Energy  482100658584410
# 34821              [Speak up!]          We Stand For Energy  482100658584410
#
#       impressions.lower_bound impressions.upper_bound spend.lower_bound  \
# 0                       20000                   24999               600
# 1                       25000                   29999               800
# 2                       15000                   19999                 0
# 3                        7000                    7999                 0
# 4                       10000                   14999                 0
# ...                       ...                     ...               ...
# 34817                       0                     999                 0
# 34818                    1000                    1999                 0
# 34819                    4000                    4999                 0
# 34820                   50000                   59999              1000
# 34821                   15000                   19999               300
#
#       spend.upper_bound
# 0                   699
# 1                   899
# 2                    99
# 3                    99
# 4                    99
# ...                 ...
# 34817                99
# 34818                99
# 34819                99
# 34820              1499
# 34821               399
#
# [34822 rows x 18 columns]

# %% [markdown]
# ### Clean & Export Data

# %% [markdown]
# ### For Summary Table

# %%
# check NaNs:
# res['ad_delivery_stop_time'][res['ad_delivery_stop_time'].isna()]

# fill NaN with '999'
res['ad_delivery_stop_time'] = res['ad_delivery_stop_time'].fillna('999')

# %%
# create 'ad start month' and 'ad start year' column
res['ad_start_month'] = res['ad_delivery_start_time'].str.split('-').str[1].astype(int)
res['ad_start_year'] = res['ad_delivery_start_time'].str.split('-').str[0].astype(int)

# %%
# convert string to integer
res['spend.lower_bound'] = res['spend.lower_bound'].astype('int')
res['spend.upper_bound'] = res['spend.upper_bound'].astype('int').round(-2)

# %%
# title case for bylines column
res['bylines'] = res['bylines'].str.title()

# %%
res[0:1]
# Out:
#                  id ad_delivery_start_time ad_delivery_stop_time  \
# 0  1343142396186676             2022-01-13            2022-05-31
#
#                                      ad_snapshot_url  \
# 0  https://www.facebook.com/ads/archive/render_ad...
#
#                        bylines  \
# 0  Affordable Energy Coalition
#
#                                   delivery_by_region  \
# 0  [{'percentage': '0.000545', 'region': 'Idaho'}...
#
#                             demographic_distribution    publisher_platforms  \
# 0  [{'percentage': '0.000133', 'age': '13-17', 'g...  [facebook, instagram]
#
#                                   ad_creative_bodies  \
# 0  [Middle-class families are being pushed out of...
#
#          ad_creative_link_captions    ad_creative_link_descriptions  \
# 0  [affordableenergycoalition.org]  [Tell the City What’s at Stake]
#
#    ad_creative_link_titles                    page_name          page_id  \
# 0  [You Can Fight the Ban]  Affordable Energy Coalition  106039214814684
#
#   impressions.lower_bound impressions.upper_bound  spend.lower_bound  \
# 0                   20000                   24999                600
#
#    spend.upper_bound  ad_start_month  ad_start_year
# 0                700               1           2022

# %%
# export raw data
res.to_csv("../data/all-front-group-ads-061223.csv")

# %%
resjson = res[['page_name', 'id', 'spend.lower_bound', 'spend.upper_bound']].groupby('page_name').agg({'id':'count', 'spend.lower_bound': 'sum', 'spend.upper_bound': 'sum'}).reset_index().rename(columns={'page_name':'name', 'id':'ads', 'spend.lower_bound': 'lowerAmount', 'spend.upper_bound':'upperAmount'}).sort_values(by="upperAmount", ascending=False).reset_index(drop=True)

# %%
resjson
# Out:
#                                           name    ads  lowerAmount  \
# 0                              Energy Citizens  17341      8569800
# 1                 Voices for Cooperative Power   1663       994900
# 2     Natural Allies for a Clean Energy Future   1946       829500
# 3                     The Empowerment Alliance   2205       590000
# 4                     Consumer Energy Alliance   2229       583100
# 5                  Alliance for Michigan Power   2970       207200
# 6       Citizens Energizing Michigan's Economy   1100       237300
# 7             Affordable Energy for New Jersey   2204        89900
# 8                       Seniors Across America    210       238300
# 9                           Power for Tomorrow    315       210100
# 10             Partnership for Energy Progress    317       175400
# 11                           Smarter NY Energy    193       131800
# 12                         We Stand For Energy   1015        68700
# 13           New Yorkers For Affordable Energy     12        74100
# 14                  Cooperative Action Network    282        32000
# 15                 Affordable Energy Coalition    117        45200
# 16                             Save Our Stoves     22        43500
# 17                         Real Coalition Iowa    446         3700
# 18                     SC Clean Energy For All    132         6800
# 19  Californians for Balanced Energy Solutions     49        12500
# 20     Coalition for Cleaner Affordable Energy     20         5500
# 21         Natural Gas for the Next Generation     33            0
# 22                          Jobkeeper Alliance      1         1500
#
#     upperAmount
# 0      11932000
# 1       1363200
# 2       1183800
# 3        924000
# 4        922500
# 5        526800
# 6        378700
# 7        315100
# 8        314300
# 9        275100
# 10       239100
# 11       177200
# 12       176600
# 13        88200
# 14        66400
# 15        65300
# 16        51600
# 17        48700
# 18        20400
# 19        19000
# 20         7900
# 21         3300
# 22         2000

# %%
# export data
resjson.to_json('../data/summary-061223.json', orient = 'records')

# %% [markdown]
# ### For Individual Tables

# %%
# unpack the dataset to access region data
result = pd.concat([res.explode('delivery_by_region').drop(['delivery_by_region'], axis=1),
           res.explode('delivery_by_region')['delivery_by_region'].apply(pd.Series)],
          axis=1)

# %%
# convert to float type 
result['percentage'] = result['percentage'].astype(float)

# %%
# calculate lower & upper amount spent per region
result['lowerAmount'] = result['percentage'] * result['spend.lower_bound']
result['upperAmount'] = result['percentage'] * result['spend.upper_bound']

# %%
# view data
result[['page_name', 'region', 'lowerAmount', 'upperAmount']].groupby(['page_name', 'region']).sum(['lowerAmount', 'upperAmount']).reset_index().rename(columns={'page_name':'name'})
# Out:
#                              name                            region  \
# 0     Affordable Energy Coalition                  British Columbia
# 1     Affordable Energy Coalition                        California
# 2     Affordable Energy Coalition                          Colorado
# 3     Affordable Energy Coalition                             Idaho
# 4     Affordable Energy Coalition                           Indiana
# ...                           ...                               ...
# 3072          We Stand For Energy                        Washington
# 3073          We Stand For Energy  Washington, District of Columbia
# 3074          We Stand For Energy                     West Virginia
# 3075          We Stand For Energy                         Wisconsin
# 3076          We Stand For Energy                           Wyoming
#
#       lowerAmount  upperAmount
# 0          0.0940       0.1410
# 1          0.1195       0.1337
# 2          0.1080       0.1260
# 3         94.9952     136.0257
# 4          0.0700       0.1050
# ...           ...          ...
# 3072     440.3581    1014.7315
# 3073     762.8655    1618.5424
# 3074     434.9903     861.6881
# 3075     368.0419     788.0598
# 3076      48.5625     106.9739
#
# [3077 rows x 4 columns]

# %%
# if the percentage amount is less 10%, don't include it
# result.query("percentage >.10")
result.query(" page_name == 'Cooperative Action Network' ")
# Out:
#                      id ad_delivery_start_time ad_delivery_stop_time  \
# 32991   750221999168886             2020-10-15            2020-11-04
# 32997  2866632236898388             2020-10-15            2020-11-04
# 32999   384818842924661             2020-10-15            2020-11-04
# 33006   374171577100739             2020-10-05            2020-10-15
# 33008   344688343463209             2020-10-05            2020-10-15
# ...                 ...                    ...                   ...
# 33805  2103515723243218             2018-05-18            2018-05-25
# 33805  2103515723243218             2018-05-18            2018-05-25
# 33805  2103515723243218             2018-05-18            2018-05-25
# 33805  2103515723243218             2018-05-18            2018-05-25
# 33805  2103515723243218             2018-05-18            2018-05-25
#
#                                          ad_snapshot_url  \
# 32991  https://www.facebook.com/ads/archive/render_ad...
# 32997  https://www.facebook.com/ads/archive/render_ad...
# 32999  https://www.facebook.com/ads/archive/render_ad...
# 33006  https://www.facebook.com/ads/archive/render_ad...
# 33008  https://www.facebook.com/ads/archive/render_ad...
# ...                                                  ...
# 33805  https://www.facebook.com/ads/archive/render_ad...
# 33805  https://www.facebook.com/ads/archive/render_ad...
# 33805  https://www.facebook.com/ads/archive/render_ad...
# 33805  https://www.facebook.com/ads/archive/render_ad...
# 33805  https://www.facebook.com/ads/archive/render_ad...
#
#                                                 bylines  \
# 32991  National Rural Electric Cooperatives Association
# 32997  National Rural Electric Cooperatives Association
# 32999  National Rural Electric Cooperatives Association
# 33006  National Rural Electric Cooperatives Association
# 33008  National Rural Electric Cooperatives Association
# ...                                                 ...
# 33805                                               NaN
# 33805                                               NaN
# 33805                                               NaN
# 33805                                               NaN
# 33805                                               NaN
#
#                                 demographic_distribution publisher_platforms  \
# 32991  [{'percentage': '0.001451', 'age': '45-54', 'g...          [facebook]
# 32997  [{'percentage': '0.001697', 'age': '65+', 'gen...          [facebook]
# 32999  [{'percentage': '0.000733', 'age': '45-54', 'g...          [facebook]
# 33006  [{'percentage': '0.036011', 'age': '25-34', 'g...          [facebook]
# 33008  [{'percentage': '0.028617', 'age': '25-34', 'g...          [facebook]
# ...                                                  ...                 ...
# 33805  [{'percentage': '0.012841', 'age': '18-24', 'g...          [facebook]
# 33805  [{'percentage': '0.012841', 'age': '18-24', 'g...          [facebook]
# 33805  [{'percentage': '0.012841', 'age': '18-24', 'g...          [facebook]
# 33805  [{'percentage': '0.012841', 'age': '18-24', 'g...          [facebook]
# 33805  [{'percentage': '0.012841', 'age': '18-24', 'g...          [facebook]
#
#                                       ad_creative_bodies  \
# 32991  [$12,758,986+ in #RuralElectric savings could ...
# 32997  [$142,046,500+ in #RuralElectric savings could...
# 32999  [$366,225+ in #RuralElectric savings could hap...
# 33006  [$732,151,740+ in #RuralElectric savings could...
# 33008  [$3,265,150+ in #RuralElectric savings could h...
# ...                                                  ...
# 33805  ["With electricity prices flat in most markets...
# 33805  ["With electricity prices flat in most markets...
# 33805  ["With electricity prices flat in most markets...
# 33805  ["With electricity prices flat in most markets...
# 33805  ["With electricity prices flat in most markets...
#
#       ad_creative_link_captions ad_creative_link_descriptions  ...  \
# 32991                       NaN                           NaN  ...
# 32997                       NaN                           NaN  ...
# 32999                       NaN                           NaN  ...
# 33006                       NaN                           NaN  ...
# 33008                       NaN                           NaN  ...
# ...                         ...                           ...  ...
# 33805                       NaN                           NaN  ...
# 33805                       NaN                           NaN  ...
# 33805                       NaN                           NaN  ...
# 33805                       NaN                           NaN  ...
# 33805                       NaN                           NaN  ...
#
#       impressions.upper_bound spend.lower_bound spend.upper_bound  \
# 32991                    6999                 0               100
# 32997                    6999                 0               100
# 32999                    2999                 0               100
# 33006                    3999                 0               100
# 33008                    2999                 0               100
# ...                       ...               ...               ...
# 33805                     999                 0               100
# 33805                     999                 0               100
# 33805                     999                 0               100
# 33805                     999                 0               100
# 33805                     999                 0               100
#
#       ad_start_month ad_start_year   0  percentage         region  \
# 32991             10          2020 NaN    1.000000           Iowa
# 32997             10          2020 NaN    1.000000      Louisiana
# 32999             10          2020 NaN    1.000000       New York
# 33006             10          2020 NaN    1.000000          Texas
# 33008             10          2020 NaN    1.000000        Wyoming
# ...              ...           ...  ..         ...            ...
# 33805              5          2018 NaN    0.001605          Maine
# 33805              5          2018 NaN    0.006421       Maryland
# 33805              5          2018 NaN    0.001605  Massachusetts
# 33805              5          2018 NaN    0.020867       Michigan
# 33805              5          2018 NaN    0.009631        Wyoming
#
#        lowerAmount  upperAmount
# 32991          0.0     100.0000
# 32997          0.0     100.0000
# 32999          0.0     100.0000
# 33006          0.0     100.0000
# 33008          0.0     100.0000
# ...            ...          ...
# 33805          0.0       0.1605
# 33805          0.0       0.6421
# 33805          0.0       0.1605
# 33805          0.0       2.0867
# 33805          0.0       0.9631
#
# [3943 rows x 24 columns]

# %%
# export data
result[['page_name', 'region', 'lowerAmount', 'upperAmount', 'percentage']].query("percentage > 0.10").groupby(['page_name', 'region']).sum(['lowerAmount', 'upperAmount']).reset_index().rename(columns={'page_name':'name'}).to_json('../data/individual-061223.json', orient = 'records')
