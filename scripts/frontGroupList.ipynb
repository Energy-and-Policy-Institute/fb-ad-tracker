# %% [markdown]
# ### Add information to the Front Groups Data

# %%
# import libraries
import pandas as pd
import json

# %% [markdown]
# ### Create Dictionary

# %%
pageDict = {
    'Affordable Energy Coalition':'106039214814684',
    'Affordable Energy for New Jersey':'102281724942742',
    'Alliance for Michigan Power':'738063612887865',
    "Citizens Energizing Michigan's Economy":'591566840920364',
    "Consumer Energy Alliance":'49560242814',
    "The Empowerment Alliance":'101691091213750',
    "Energy Citizens":'113891694102',
    "Natural Allies for a Clean Energy Future":'100801038449520',
    "New Yorkers For Affordable Energy":'111394533709201',
    "Partnership for Energy Progress":'107500120800840',
    "Seniors Across America":'108203188195224',
    "Voices for Cooperative Power":'47710973068',
    "We Stand For Energy":'482100658584410',
    "Jobkeeper Alliance":'292970844058835',
    "Power for Tomorrow":'101242238726088',
    "Californians for Balanced Energy Solutions":'341751646428117',
    "SC Clean Energy For All":'396341921119746',
    "Real Coalition Iowa":'237209147160346',
    "Cooperative Action Network":'47710973068'
}

# %%
linkDict = {
    'Affordable Energy Coalition':"https://www.energyandpolicy.org/affordable-energy-coalition/",
    'Affordable Energy for New Jersey':"https://www.energyandpolicy.org",
    'Alliance for Michigan Power':"https://www.energyandpolicy.org/alliance-for-michigan-power/",
    "Citizens Energizing Michigan's Economy":"https://www.energyandpolicy.org/citizens-for-energizing-michigans-economy/",
    "Consumer Energy Alliance":"https://www.energyandpolicy.org/consumer-energy-alliance/",
    "The Empowerment Alliance":"https://www.energyandpolicy.org",
    "Energy Citizens":"https://www.energyandpolicy.org",
    "Natural Allies for a Clean Energy Future":"https://www.energyandpolicy.org/natural-allies-for-a-clean-energy-future/",
    "New Yorkers For Affordable Energy":"https://www.energyandpolicy.org",
    "Partnership for Energy Progress":"https://www.energyandpolicy.org/partnership-for-energy-progress/",
    "Seniors Across America":"https://www.energyandpolicy.org",
    "Voices for Cooperative Power":"https://www.energyandpolicy.org",
    "We Stand For Energy":"https://www.energyandpolicy.org",
    "Jobkeeper Alliance":'https://www.energyandpolicy.org/jobkeeper-alliance/',
    "Power for Tomorrow":'https://www.energyandpolicy.org/power-for-tomorrow/',
    "Californians for Balanced Energy Solutions":'https://www.energyandpolicy.org/californians-for-balanced-energy-solutions/',
    "SC Clean Energy For All":"https://www.energyandpolicy.org",
    "Real Coalition Iowa":"https://www.energyandpolicy.org/midamerican-and-anti-solar-real-coalition/",
    "Cooperative Action Network":"https://www.energyandpolicy.org"
}

# %% [markdown]
# ### Read In Summary Table Data

# %%
df = pd.read_json("../data/summary.json")

# %%
df2 = pd.read_json("../data/individual.json")

# %% [markdown]
# ### Add Columns: url & pageId

# %%
df['url'] = df['name'].map(linkDict)

# %%
df['pageId'] = df['name'].map(pageDict)

# %%
df['pageId'] = df['pageId'].astype(int)

# %%
df
# Out:
#                                           name   ads  lowerAmount  \
# 0                 Voices for Cooperative Power   922       711700
# 1                     Consumer Energy Alliance  2151       569900
# 2                     The Empowerment Alliance  2102       562500
# 3     Natural Allies for a Clean Energy Future  1259       491800
# 4                  Alliance for Michigan Power  2816       149100
# 5       Citizens Energizing Michigan's Economy  1100       229800
# 6                           Power for Tomorrow   192       161600
# 7              Partnership for Energy Progress   189       114900
# 8                          We Stand For Energy   969        48900
# 9             Affordable Energy for New Jersey  1063        39800
# 10                      Seniors Across America   139        79000
# 11                  Cooperative Action Network   422        36500
# 12                 Affordable Energy Coalition   117        45200
# 13                         Real Coalition Iowa   446         3700
# 14                     SC Clean Energy For All   132         6800
# 15  Californians for Balanced Energy Solutions    49        12500
# 16           New Yorkers For Affordable Energy     4         7200
# 17                          Jobkeeper Alliance     1         1500
#
#     upperAmount                                                url  \
# 0        947000                    https://www.energyandpolicy.org
# 1        899900  https://www.energyandpolicy.org/consumer-energ...
# 2        882200                    https://www.energyandpolicy.org
# 3        701400  https://www.energyandpolicy.org/natural-allies...
# 4        446100  https://www.energyandpolicy.org/alliance-for-m...
# 5        370800  https://www.energyandpolicy.org/citizens-for-e...
# 6        204500  https://www.energyandpolicy.org/power-for-tomo...
# 7        157100  https://www.energyandpolicy.org/partnership-fo...
# 8        148200                    https://www.energyandpolicy.org
# 9        146900                    https://www.energyandpolicy.org
# 10       107100                    https://www.energyandpolicy.org
# 11        84900                    https://www.energyandpolicy.org
# 12        65300  https://www.energyandpolicy.org/affordable-ene...
# 13        48700  https://www.energyandpolicy.org/midamerican-an...
# 14        20400                    https://www.energyandpolicy.org
# 15        19000  https://www.energyandpolicy.org/californians-f...
# 16         8500                    https://www.energyandpolicy.org
# 17         2000  https://www.energyandpolicy.org/jobkeeper-alli...
#
#              pageId
# 0       47710973068
# 1       49560242814
# 2   101691091213750
# 3   100801038449520
# 4   738063612887865
# 5   591566840920364
# 6   101242238726088
# 7   107500120800840
# 8   482100658584410
# 9   102281724942742
# 10  108203188195224
# 11      47710973068
# 12  106039214814684
# 13  237209147160346
# 14  396341921119746
# 15  341751646428117
# 16  111394533709201
# 17  292970844058835

# %% [markdown]
# ### Export to JSON

# %%
# storing data in JSON format
df.to_json('../data/summaryClean.json', orient = 'records')
